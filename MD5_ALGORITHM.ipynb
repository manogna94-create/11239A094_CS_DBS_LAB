# %% [markdown]
# <a href="https://colab.research.google.com/github/manogna94-create/11239A094_CS_DBS_LAB/blob/main/MD5_ALGORITHM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import hashlib

text = "The quick brown fox jumps over the lazy dog"

# encode the string and generate MD5 hash
result = hashlib.md5(text.encode())

print("Input String: ", text)
print("MD5 Hash: ", result.hexdigest())
# Out:
# Input String:  The quick brown fox jumps over the lazy dog
# MD5 Hash:  9e107d9d372bb6826bd81d3542a419d6
