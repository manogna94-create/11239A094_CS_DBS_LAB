# %% [markdown]
# <a href="https://colab.research.google.com/github/manogna94-create/11239A094_CS_DBS_LAB/blob/main/DIFFIEE_HELLMAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def power(a, b, mod):
    """Calculates (a^b) % mod using recursive exponentiation by squaring."""
    if b == 1:
        return a % mod

    t = power(a, b // 2, mod)

    if b % 2 == 0:
        return (t * t) % mod
    else:
        return ((t * t) % mod * a) % mod

def main():
    # Input values
    n = int(input("Enter the value of n (prime number): "))
    g = int(input("Enter the value of g (generator): "))

    x = int(input("Enter the value of x for the first person: "))
    a = power(g, x, n)

    y = int(input("Enter the value of y for the second person: "))
    b = power(g, y, n)

    # Calculate the shared keys
    key1 = power(b, x, n)
    key2 = power(a, y, n)

    print(f"Key for the first person is: {key1}")
    print(f"Key for the second person is: {key2}")

if __name__ == "__main__":
    main()
# Out:
# Enter the value of n (prime number): 11
# Enter the value of g (generator): 9
# Enter the value of x for the first person: 1
# Enter the value of y for the second person: 3
# Key for the first person is: 3
# Key for the second person is: 3
